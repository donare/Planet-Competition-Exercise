# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pickle

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
assert torch.cuda.is_available()

# %%
assert torch.backends.cudnn.enabled

# %%
from IPython.core import page
temp = page.page
page.page = print

# %pycat scripts/data_imports.py

page.page=temp
# Out:
# from functools import reduce
# import pandas as pd
#
# path = "../data/"
# train_path = path + "train-jpg/"
# train = pd.read_csv(path + "train_v2.csv")
#
# tags = list(reduce(lambda x, y: x | set(y.split()), train['tags'], set()))
#
# for tag in tags:
#     train[tag] = train['tags'].apply(lambda x: tag in x.split())
#
# train = train.drop(labels='tags', axis=1)

# %%
# %run scripts/data_imports.py

# %%
train
# Out:
#         image_name  cloudy  clear  blow_down   haze  conventional_mine  \
# 0          train_0   False  False      False   True              False
# 1          train_1   False   True      False  False              False
# 2          train_2   False   True      False  False              False
# 3          train_3   False   True      False  False              False
# 4          train_4   False   True      False  False              False
# 5          train_5   False  False      False   True              False
# 6          train_6   False   True      False  False              False
# 7          train_7   False  False      False   True              False
# 8          train_8   False   True      False  False              False
# 9          train_9   False   True      False  False              False
# 10        train_10   False   True      False  False              False
# 11        train_11   False   True      False  False              False
# 12        train_12    True  False      False  False              False
# 13        train_13   False   True      False  False              False
# 14        train_14    True  False      False  False              False
# 15        train_15   False   True      False  False              False
# 16        train_16   False   True      False  False              False
# 17        train_17   False  False      False  False              False
# 18        train_18   False   True      False  False              False
# 19        train_19   False   True      False  False              False
# 20        train_20   False   True      False  False              False
# 21        train_21   False   True      False  False              False
# 22        train_22   False  False      False  False              False
# 23        train_23   False   True      False  False              False
# 24        train_24   False  False      False  False               True
# 25        train_25   False   True      False  False              False
# 26        train_26    True  False      False  False              False
# 27        train_27   False  False      False  False              False
# 28        train_28   False   True      False  False              False
# 29        train_29   False  False      False  False              False
# ...            ...     ...    ...        ...    ...                ...
# 40449  train_40449   False   True      False  False              False
# 40450  train_40450   False  False      False  False              False
# 40451  train_40451   False   True      False  False              False
# 40452  train_40452   False   True      False  False              False
# 40453  train_40453   False   True      False  False              False
# 40454  train_40454   False   True      False  False              False
# 40455  train_40455   False  False      False  False               True
# 40456  train_40456   False   True      False  False              False
# 40457  train_40457   False   True      False  False              False
# 40458  train_40458   False   True      False  False              False
# 40459  train_40459   False   True      False  False              False
# 40460  train_40460   False   True      False  False              False
# 40461  train_40461    True  False      False  False              False
# 40462  train_40462   False   True      False  False              False
# 40463  train_40463   False  False      False   True              False
# 40464  train_40464   False  False      False  False              False
# 40465  train_40465   False   True       True  False              False
# 40466  train_40466   False   True      False  False              False
# 40467  train_40467   False   True      False  False              False
# 40468  train_40468   False   True      False  False              False
# 40469  train_40469   False  False      False   True              False
# 40470  train_40470   False   True      False  False              False
# 40471  train_40471   False   True      False  False              False
# 40472  train_40472   False   True      False  False              False
# 40473  train_40473   False   True      False  False              False
# 40474  train_40474   False   True      False  False              False
# 40475  train_40475    True  False      False  False              False
# 40476  train_40476   False   True      False  False              False
# 40477  train_40477   False   True      False  False              False
# 40478  train_40478   False  False      False  False              False
#
#        primary  habitation  blooming  agriculture  artisinal_mine  \
# 0         True       False     False        False           False
# 1         True       False     False         True           False
# 2         True       False     False        False           False
# 3         True       False     False        False           False
# 4         True        True     False         True           False
# 5         True       False     False        False           False
# 6         True       False     False         True           False
# 7         True       False     False        False           False
# 8         True       False     False         True           False
# 9         True       False     False         True           False
# 10        True       False     False         True           False
# 11        True       False     False        False           False
# 12       False       False     False        False           False
# 13        True       False     False        False           False
# 14       False       False     False        False           False
# 15        True       False     False        False           False
# 16        True       False     False        False           False
# 17        True       False     False        False           False
# 18        True       False     False        False           False
# 19        True       False     False         True           False
# 20        True       False     False         True           False
# 21        True       False     False        False           False
# 22        True       False     False        False           False
# 23        True       False     False         True           False
# 24        True       False     False        False           False
# 25        True       False     False        False           False
# 26       False       False     False        False           False
# 27        True       False     False         True           False
# 28        True       False     False        False           False
# 29        True       False     False        False           False
# ...        ...         ...       ...          ...             ...
# 40449     True       False     False        False           False
# 40450     True       False     False         True           False
# 40451     True       False     False        False           False
# 40452     True       False     False        False           False
# 40453     True       False     False        False            True
# 40454     True       False     False        False           False
# 40455     True       False     False         True           False
# 40456     True       False     False        False           False
# 40457     True       False     False        False           False
# 40458     True       False     False         True           False
# 40459     True       False     False        False           False
# 40460     True       False     False        False           False
# 40461    False       False     False        False           False
# 40462     True       False     False        False           False
# 40463     True       False     False         True           False
# 40464     True       False     False         True           False
# 40465     True       False     False        False           False
# 40466     True       False     False        False           False
# 40467     True       False     False         True           False
# 40468     True       False     False         True           False
# 40469     True       False     False        False           False
# 40470     True        True     False        False           False
# 40471     True       False     False        False           False
# 40472     True       False     False         True           False
# 40473     True        True     False         True           False
# 40474     True       False     False        False           False
# 40475    False       False     False        False           False
# 40476     True       False     False         True           False
# 40477     True       False     False         True           False
# 40478     True       False     False         True           False
#
#        cultivation  bare_ground  slash_burn  selective_logging  water  \
# 0            False        False       False              False  False
# 1            False        False       False              False   True
# 2            False        False       False              False  False
# 3            False        False       False              False  False
# 4            False        False       False              False  False
# 5            False        False       False              False   True
# 6             True        False       False              False   True
# 7            False        False       False              False  False
# 8             True        False       False              False  False
# 9             True        False       False              False  False
# 10           False        False        True              False   True
# 11           False        False       False              False   True
# 12           False        False       False              False  False
# 13           False        False       False              False  False
# 14           False        False       False              False  False
# 15           False        False       False              False  False
# 16           False        False       False              False  False
# 17           False        False       False              False  False
# 18           False        False       False              False  False
# 19           False        False       False              False  False
# 20           False        False       False              False   True
# 21           False        False       False              False   True
# 22           False        False       False              False  False
# 23           False        False       False              False  False
# 24           False        False       False              False  False
# 25           False        False       False              False  False
# 26           False        False       False              False  False
# 27           False        False       False              False   True
# 28           False        False       False              False  False
# 29           False        False       False              False  False
# ...            ...          ...         ...                ...    ...
# 40449        False        False       False              False   True
# 40450         True        False       False              False  False
# 40451        False        False       False              False  False
# 40452        False        False       False              False  False
# 40453        False        False       False              False  False
# 40454        False        False       False              False  False
# 40455        False        False       False              False  False
# 40456        False        False       False              False  False
# 40457        False        False       False               True   True
# 40458        False        False       False              False  False
# 40459        False        False       False              False   True
# 40460        False        False       False              False  False
# 40461        False        False       False              False  False
# 40462        False        False       False              False  False
# 40463        False        False       False              False  False
# 40464        False        False       False              False  False
# 40465        False        False       False              False  False
# 40466        False        False       False              False  False
# 40467        False        False       False              False  False
# 40468        False        False       False              False  False
# 40469        False        False       False              False   True
# 40470        False        False       False              False  False
# 40471        False        False       False              False  False
# 40472        False        False       False              False  False
# 40473        False        False       False              False  False
# 40474        False        False       False              False  False
# 40475        False        False       False              False  False
# 40476        False        False       False              False  False
# 40477        False        False       False              False  False
# 40478         True        False       False              False  False
#
#        partly_cloudy   road
# 0              False  False
# 1              False  False
# 2              False  False
# 3              False  False
# 4              False   True
# 5              False  False
# 6              False  False
# 7              False  False
# 8              False  False
# 9              False   True
# 10             False  False
# 11             False  False
# 12             False  False
# 13             False  False
# 14             False  False
# 15             False  False
# 16             False  False
# 17              True  False
# 18             False  False
# 19             False   True
# 20             False  False
# 21             False   True
# 22              True  False
# 23             False   True
# 24              True  False
# 25             False  False
# 26             False  False
# 27              True  False
# 28             False  False
# 29              True  False
# ...              ...    ...
# 40449          False  False
# 40450           True   True
# 40451          False  False
# 40452          False  False
# 40453          False  False
# 40454          False  False
# 40455           True   True
# 40456          False  False
# 40457          False   True
# 40458          False   True
# 40459          False  False
# 40460          False  False
# 40461          False  False
# 40462          False  False
# 40463          False  False
# 40464           True   True
# 40465          False  False
# 40466          False  False
# 40467          False   True
# 40468          False  False
# 40469          False  False
# 40470          False   True
# 40471          False  False
# 40472          False  False
# 40473          False   True
# 40474          False  False
# 40475          False  False
# 40476          False  False
# 40477          False   True
# 40478           True  False
#
# [40479 rows x 18 columns]

# %%
override_idxs = False

if override_idxs == True:
    val_count = int(0.2*len(train.index))
    val_idxs = np.random.choice(train.index, size=val_count)
    output = open('val_idxs.pkl', 'wb')
    pickle.dump(val_idxs, output)
    output.close()

pkl_file = open('val_idxs.pkl', 'rb')

val_idxs = pickle.load(pkl_file)

pkl_file.close()

# %%
len(val_idxs)/len(train.index)
# Out:
# 0.19998023666592554

# %%
image_size = 200
architecture = resnext101 # = resnext101_32
batch_size = 15

tfms = tfms_from_model(architecture, image_size, aug_tfms=transforms_side_on, max_zoom=1.1)
data = ImageClassifierData.from_csv(path, 'train-jpg', f'{path}train_v2.csv', batch_size, tfms, val_idxs, suffix='.jpg', test_name='test-jpg')

# %%
learn = ConvLearner.pretrained(architecture, data, precompute=True)

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  96%|█████████▌| 1061/1105 [00:11<00:00, 95.27it/s, loss=0.318]

# %%
import matplotlib.pyplot as plt
learning_rate=10e-1
learn.sched.plot()
plt.axvline(x=learning_rate, color="red")

# %%
learn.fit(learning_rate, 9)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=9), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>
#     0      0.127574   0.113818   0.95673
#     1      0.126058   0.109247   0.957796
#     2      0.119259   0.112379   0.95649
#     3      0.122142   0.114518   0.955095
#     4      0.116372   0.105958   0.958831
#     5      0.11446    0.112078   0.956618
#     6      0.117213   0.10909    0.958245
#     7      0.117331   0.108967   0.958534
#     8      0.108386   0.107267   0.958775
# [array([0.10727]), 0.9587746111853045]

# %%
learn.precompute = False
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  98%|█████████▊| 1079/1105 [05:03<00:07,  3.55it/s, loss=0.401]

# %%
learning_rate=2*10e-1
learn.sched.plot()
plt.axvline(x=learning_rate, color="red")

# %%
learn.fit(learning_rate, 3, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>
#     0      0.109214   0.100654   0.960498
#     1      0.10481    0.101183   0.960346
#     2      0.111993   0.101123   0.960434
# [array([0.10112]), 0.9604342088592756]

# %%
learn.save('lastlayer')

# %%
learn.load('lastlayer')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   0%|          | 0/1105 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-d81c6bd29d71> in <module>()
# ----> 1 learn.lr_find()
#
# ~/Projekte/Planet-Competition-Exercise/notebooks/fastai/learner.py in lr_find(self, start_lr, end_lr, wds, linear, **kwargs)
#     345         layer_opt = self.get_layer_opt(start_lr, wds)
#     346         self.sched = LR_Finder(layer_opt, len(self.data.trn_dl), end_lr, linear=linear)
# --> 347         self.fit_gen(self.model, self.data, layer_opt, 1, **kwargs)
#     348         self.load('tmp')
#     349
#
# ~/Projekte/Planet-Competition-Exercise/notebooks/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, use_swa, swa_start, swa_eval_freq, **kwargs)
#     249             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, fp16=self.fp16,
#     250             swa_model=self.swa_model if use_swa else None, swa_start=swa_start,
# --> 251             swa_eval_freq=swa_eval_freq, **kwargs)
#     252
#     253     def get_layer_groups(self): return self.models.get_layer_groups()
#
# ~/Projekte/Planet-Competition-Exercise/notebooks/fastai/model.py in fit(model, data, n_epochs, opt, crit, metrics, callbacks, stepper, swa_model, swa_start, swa_eval_freq, visualize, **kwargs)
#     138             batch_num += 1
#     139             for cb in callbacks: cb.on_batch_begin()
# --> 140             loss = model_stepper.step(V(x),V(y), epoch)
#     141             avg_loss = avg_loss * avg_mom + loss * (1-avg_mom)
#     142             debias_loss = avg_loss / (1 - avg_mom**batch_num)
#
# ~/Projekte/Planet-Competition-Exercise/notebooks/fastai/model.py in step(self, xs, y, epoch)
#      48     def step(self, xs, y, epoch):
#      49         xtra = []
# ---> 50         output = self.m(*xs)
#      51         if isinstance(output,tuple): output,*xtra = output
#      52         if self.fp16: self.m.zero_grad()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/Projekte/Planet-Competition-Exercise/notebooks/fastai/models/resnext_101_32x4d.py in forward(self, input)
#      22 class LambdaMap(LambdaBase):
#      23     def forward(self, input):
# ---> 24         return list(map(self.lambda_func,self.forward_prepare(input)))
#      25
#      26 class LambdaReduce(LambdaBase):
#
# ~/Projekte/Planet-Competition-Exercise/notebooks/fastai/models/resnext_101_32x4d.py in forward_prepare(self, input)
#      13         output = []
#      14         for module in self._modules.values():
# ---> 15             output.append(module(input))
#      16         return output if output else input
#      17
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/activation.py in forward(self, input)
#      41
#      42     def forward(self, input):
# ---> 43         return F.threshold(input, self.threshold, self.value, self.inplace)
#      44
#      45     def __repr__(self):
#
# RuntimeError: cuda runtime error (2) : out of memory at /opt/conda/conda-bld/pytorch_1518244421288/work/torch/lib/THC/generic/THCStorage.cu:58
